# %% [markdown]
# **Omkar Rajendra Shinde**
#
# PRN - 202201040190
#
# Roll no - 582
#
# MID SEM PRACTICAL

# %%
import csv
file1 = open('dataset1.csv', 'r')
dataset = csv.reader(file1)
dataset = list(dataset)

# %%
winners = []
for i in range(len(dataset)):
  if dataset[i][0] not in winners:
    winners.append(dataset[i][4])

print(winners)
# Out:
# ['Winner', 'India', 'Sri Lanka', 'India', 'India', 'India', 'Sri Lanka', 'Pakistan', 'Sri Lanka', 'Sri Lanka', 'India', 'Pakistan', 'Sri Lanka', 'India']

# %%
import statistics
winners.remove('Winner')
winners.sort()
print("Country that has most Asia Cups")
statistics.mode(winners)
# Out:
# Country that has most Asia Cups
# 'India'

# %%
Host = []
for i in range(len(dataset)):
  if dataset[i][0] not in Host:
    Host.append(dataset[i][2])

print(Host)
# Out:
# ['Host', 'UAE', 'Sri Lanka', 'Bangladesh', 'India', 'UAE', 'Sri Lanka', 'Bangladesh', 'Sri Lanka', 'Pakistan', 'Sri Lanka', 'Bangladesh', 'Bangladesh', 'Bangladesh']

# %%
print("Country that Host the most asia cup tournament")
Host.remove('Host')
statistics.mode(Host)
# Out:
# Country that Host the most asia cup tournament
# 'Bangladesh'

# %%
form=[]
yrup={}
f=open("dataset1.csv","rt")
data=f.readline()
while(True):
  data=f.readline() 
  if not data:
      break;
  form.append(temp[1])    
  data=data.replace("\n","")
  temp=data.split(",")
  yrup.update({temp[0]:temp[6]})
print("The runner up for the year 1988 is",yrup.get("1988"))
print("The runner up for the year 2004 is",yrup.get("2004"))
print("The runner up for the year 2016 is",yrup.get("2016"))
# Out:
# The runner up for the year 1988 is Sri Lanka
# The runner up for the year 2004 is India
# The runner up for the year 2016 is Bangladesh

# %%
for y in form:
  if y=="ODI":
    print(y)
  if y=="T20I":
    print(y)
print("In total there are 2 formats")
# Out:
# T20I
# ODI
# ODI
# ODI
# ODI
# T20I
# ODI
# ODI
# ODI
# T20I
# ODI
# ODI
# ODI
# In total there are 2 formats
