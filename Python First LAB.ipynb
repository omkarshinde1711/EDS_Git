# %%
print ("Hello world")

# %%
print ("This is the first py program")

# %%
sum=0
i=1
while (i<=10):
  sum=sum+i
  i=i+1
print(sum)
# Out:
# 55

# %%
def add(a,b):
  c=a+b
  return c
x=int(input())
y=int(input())

print(add(x,y))
# Out:
# 5
# 54
# 59

# %%
def add(a=10,b=5):
  c=a+b
  return c

# %%
def sum(a,b,c):
  s=a+b+c
  return s
x=int(input())
y=int(input())
z=int(input())
s1=sum(x,y,z)
avg=s1/3
print(avg)
# Out:
# 8
# 15
# 65
# 29.333333333333332

# %%
def sq(x):
  x=x*x
  return x
  if x<=10:
  sq(x) 
x=int(input())

# %%
def table(n,i):
  print(n*i)
  i=i+1
  if(i<=10):
    table(n,i)
x=int(input())
y=int(input())
table(x,y)
# Out:
# 8
# 1
# 8
# 16
# 24
# 32
# 40
# 48
# 56
# 64
# 72
# 80

# %% [markdown]
# Lambda Function Program

# %%
x=lambda a,b :a+b
print (x(20,30))
# Out:
# 50

# %% [markdown]
# **Greater Than Function**

# %%
s=lambda a,b : a if a>b else b
print(s(20,30))
# Out:
# 30

# %%
s=lamda a : print(even) if a%2=0 else print(odd)
print(a(6))
# Out:
#   File "<ipython-input-20-96b5189670a5>", line 1
#     s=lamda a : print(even) if a%2=0 else print(odd)
#             ^
# SyntaxError: invalid syntax

# %% [markdown]
# r for read
#
# t text
#
# b binary
#
# a append
#
# w write
#
# Object
#
# # f = open (path)

# %%
from google.colab import drive

drive.mount('/content/gdrive/', force_remount=True)
# Out:
# Mounted at /content/gdrive/

# %%
# %cd gdrive/MyDrive/
# Out:
# [Errno 2] No such file or directory: 'gdrive/MyDrive/'
# /content/gdrive/MyDrive

# %%
f = open ("/content/gdrive/hello.txt")
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-36-25185b24da90> in <cell line: 1>()
# ----> 1 f = open ("/content/gdrive/hello.txt")
#
# FileNotFoundError: [Errno 2] No such file or directory: '/content/gdrive/hello.txt'
